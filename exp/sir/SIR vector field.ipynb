# %% [markdown]
# # Import backage

# %%
import sys
sys.path.append("../..")
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import random
# %matplotlib inline

# %%
import torch
from torch import nn
from torch import distributions
from torch.nn.parameter import Parameter
from exp.sir.train import train
from exp.sir.train import train_plus
from models_new import Renorm_Dynamic
from exp.sir.dynamic_models_sis_new import Simple_Spring_Model
from exp.sir.vector_field import mesh
from exp.sir.vector_field import transit
from datetime import datetime
t0 = datetime.now()


use_cuda = torch.cuda.is_available()
device = torch.device('cuda:0') if use_cuda else torch.device('cpu')
device
# Out:
# device(type='cuda', index=0)

# %% [markdown]
# # Generate data

# %%
mul_batch_size = [0,10,4500,1500]
sigma = 0.03
rou = -0.5
steps = 7
dt = 0.01
interval = 100
steps2 = 10
seed = 2050
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
spring = Simple_Spring_Model(device=device)
test_data = spring.generate_multistep_sir(size_list=[500,500], steps=10*interval, sigma=sigma, rou=rou,lam=1,miu=0.5,dt=dt,interval=interval) 
train_data = spring.generate_multistep_sir(size_list=mul_batch_size, steps=steps*interval, sigma=sigma,rou=rou,lam=1,miu=0.5,dt=dt,interval=interval)

# %% [markdown]
# # Train

# %%
sz = 4
scale = 2
L = 1
mae2_w = 3
T_total = 30001
eis_nisp, term1s_nisp, term2s_nisp, losses_nisp, MAEs_mstep_nisp, net = train_plus(train_data=train_data, test_data=test_data, 
                                                                         sigma=sigma, rou=rou, sz=sz, scale=scale, L=L, 
                                                                         mae2_w=mae2_w, dt=dt, T2=T_total,framework='nis',steps2=steps2,interval=interval)
torch.save(net.state_dict(), f'mdl_data/nis steps10 exp-0.2t interval100 seed={seed}.mdl')
# Out:
# check point-------o_0-> 11:16:52.139829; lasting 0:00:20.349267 seconds
# Epoch: 0
# Train loss: 0.2538
# dEI: 0.4862
# term1: -0.3842
# term2: 1.3566
# Test multistep loss: 0.6671
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 11:17:00.084825; lasting 0:00:07.944996 seconds
# check point-------o_0-> 11:19:14.991107; lasting 0:02:14.906282 seconds
# Epoch: 500
# Train loss: 0.0486
# dEI: 0.9831
# term1: 0.6653
# term2: 1.3008
# Test multistep loss: 0.2205
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 11:19:23.814448; lasting 0:00:08.823341 seconds
# check point-------o_0-> 11:21:43.705535; lasting 0:02:19.891087 seconds
# Epoch: 1000
# Train loss: 0.0317
# dEI: 1.2462
# term1: 1.2169
# term2: 1.2756
# Test multistep loss: 0.2103
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 11:21:53.822847; lasting 0:00:10.117312 seconds
# check point-------o_0-> 11:24:06.617354; lasting 0:02:12.794507 seconds
# Epoch: 1500
# Train loss: 0.0288
# dEI: 1.2755
# term1: 1.2813
# term2: 1.2698
# Test multistep loss: 0.2031
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 11:24:18.119859; lasting 0:00:11.502505 seconds
# check point-------o_0-> 11:26:36.947304; lasting 0:02:18.827445 seconds
# Epoch: 2000
# Train loss: 0.0309
# dEI: 1.3106
# term1: 1.3449
# term2: 1.2763
# Test multistep loss: 0.2048
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 11:26:47.733302; lasting 0:00:10.785998 seconds
# check point-------o_0-> 11:28:58.464780; lasting 0:02:10.731478 seconds
# Epoch: 2500
# Train loss: 0.0280
# dEI: 1.3812
# term1: 1.4874
# term2: 1.2751
# Test multistep loss: 0.1963
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 11:29:09.956883; lasting 0:00:11.492103 seconds
# check point-------o_0-> 11:31:30.322800; lasting 0:02:20.365917 seconds
# Epoch: 3000
# Train loss: 0.0270
# dEI: 1.3954
# term1: 1.5126
# term2: 1.2781
# Test multistep loss: 0.2022
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 11
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 12:43:50.442923; lasting 0:00:10.348003 seconds
# check point-------o_0-> 12:46:14.231704; lasting 0:02:23.788781 seconds
# Epoch: 17500
# Train loss: 0.0185
# dEI: 1.1197
# term1: 1.1901
# term2: 1.0493
# Test multistep loss: 0.2091
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 12:46:24.166502; lasting 0:00:09.934798 seconds
# check point-------o_0-> 12:48:34.098651; lasting 0:02:09.932149 seconds
# Epoch: 18000
# Train loss: 0.0224
# dEI: 1.1327
# term1: 1.2295
# term2: 1.0358
# Test multistep loss: 0.2102
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 12:48:43.686147; lasting 0:00:09.587496 seconds
# check point-------o_0-> 12:50:59.051733; lasting 0:02:15.365586 seconds
# Epoch: 18500
# Train loss: 0.0189
# dEI: 1.1268
# term1: 1.2168
# term2: 1.0369
# Test multistep loss: 0.2127
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 12:51:07.765963; lasting 0:00:08.714230 seconds
# check point-------o_0-> 12:53:24.587154; lasting 0:02:16.821191 seconds
# Epoch: 19000
# Train loss: 0.0183
# dEI: 1.1628
# term1: 1.3008
# term2: 1.0247
# Test multistep loss: 0.2176
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 12:53:33.822670; lasting 0:00:09.235516 seconds
# check point-------o_0-> 12:55:45.106653; lasting 0:02:11.283983 seconds
# Epoch: 19500
# check point-------o_0-> 13:13:06.939060; lasting 0:01:56.209139 seconds
# Epoch: 23500
# Train loss: 0.0183
# dEI: 1.1986
# term1: 1.4248
# term2: 0.9723
# Test multistep loss: 0.2169
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 13:13:16.129639; lasting 0:00:09.190579 seconds
# check point-------o_0-> 13:31:33.856363; lasting 0:02:27.635384 seconds
# Epoch: 27500
# Train loss: 0.0296
# dEI: 1.2350
# term1: 1.5485
# term2: 0.9214
# Test multistep loss: 0.2160
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 13:31:43.808520; lasting 0:00:09.952157 seconds

# %%
mul_batch_size = [0,10,4500,1500]# [0,5000,3000,1000]
sigma = 0.03
rou = -0.5
steps = 7
dt = 0.01
interval = 100
steps2 = 10

np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
spring = Simple_Spring_Model(device=device)
test_data = spring.generate_multistep_sir(size_list=[500,500], steps=10*interval, sigma=sigma, rou=rou,lam=1,miu=0.5,dt=dt,interval=interval) 
train_data = spring.generate_multistep_sir(size_list=mul_batch_size, steps=steps*interval, sigma=sigma,rou=rou,lam=1,miu=0.5,dt=dt,interval=interval)

# %%
eis_nisp, term1s_nisp, term2s_nisp, losses_nisp, MAEs_mstep_nisp, net_nisp = train_plus(train_data=train_data, test_data=test_data, 
                                                                         sigma=sigma, rou=rou, sz=sz, scale=scale, L=L, 
                                                                         mae2_w=mae2_w, dt=dt, T2=T_total,framework='nis+',steps2=steps2,interval=interval)
torch.save(net_nisp.state_dict(), f'mdl_data/nisp steps10 exp-0.2t interval100 seed={seed}.mdl')
# Out:
# check point-------o_0-> 14:04:24.134851; lasting 0:02:41.281061 seconds
# Epoch: 2500
# Train loss: 0.0274
# dEI: 1.3513
# term1: 1.4308
# term2: 1.2718
# Test multistep loss: 0.2057
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 14:04:34.043261; lasting 0:00:09.908410 seconds
# check point-------w_0-> 14:07:31.634574; lasting 0:02:57.591313 seconds
# check point-------w_1-> 14:07:31.653835; lasting 0:00:00.019261 seconds
# check point-------w_2-> 14:10:17.020509; lasting 0:02:45.366674 seconds
# check point-------w_3-> 14:10:17.032423; lasting 0:00:00.011914 seconds
# check point-------o_0-> 14:10:17.095460; lasting 0:00:00.063037 seconds
# Epoch: 3000
# Train loss: 0.0271
# dEI: 1.4187
# term1: 1.5624
# term2: 1.2750
# Test multistep loss: 0.2028
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 14:10:30.171103; lasting 0:00:13.075643 seconds
# check point-------o_0-> 14:13:26.184305; lasting 0:02:56.013202 seconds
# Epoch: 3500
# Train loss: 0.0219
# dEI: 1.7141
# term1: 2.1383
# term2: 1.2899
# Test multistep loss: 0.2041
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 14:13:37.330736; lasting 0:00:11.146431 seconds
# check point-------w_0-> 14:16:50.542091; lasting 0:03:13.211355 seconds
# check point-------w_1-> 14:16:50.559074; lasting 0:00:00.016983 seconds
# check point-------w_2-> 14:19:56.648436; lasting 0:03:06.089362 seconds
# check point-------w_3-> 14:19:56.654872; lasting 0:00:00.006436 seconds
# check point-------o_0-> 14:19:56.654920; lasting 0:00:00.000048 seconds
# Epoch: 4000
# Train loss: 0.0271
# dEI: 1.7527
# term1: 2.2131
# term2: 1.2922
# Test multistep loss: 0.2070
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 14:20:07.752010; lasting 0:00:11.097090 seconds
# check point-------o_0-> 14:22:56.586289; lasting 0:02:48.834279 seconds
# Epoch: 4500
# Train loss: 0.0298
# dEI: 1.8353
# term1: 2.3715
# term2: 1.2992
# Test multistep loss: 0.2048
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 14:23:08.384458; lasting 0:00:11.798169 seconds
# check point-------w_0-> 14:26:28.439127; lasting 0:03:20.054669 seconds
# check point-------w_1-> 14:26:28.455495; lasting 0:00:00.016368 seconds
# check point-------w_2-> 14:29:34.385623; lasting 0:03:05.930128 seconds
# check point-------w_3-> 14:29:34.400683; lasting 0:00:00.015060 seconds
# check point-------o_0-> 14:29:34.400729; lasting 0:00:00.000046 seconds
# Epoch: 5000
# Train loss: 0.0257
# dEI: 1.8992
# term1: 2.4871
# term2: 1.3114
# Test multistep loss: 0.2073
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 14:29:46.317629; lasting 0:00:11.916900 seconds
# check point-------o_0-> 14:32:47.972268; lasting 0:03:01.654639 seconds
# Epoch: 5500
# Train loss: 0.0264
# dEI: 1.9457
# term1: 2.5954
# term2: 1.2960
# Test multistep loss: 0.2000
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 14:33:00.846124; lasting 0:00:12.873856 seconds
# check point-------w_0-> 14:36:05.503550; lasting 0:03:04.657426 seconds
# check point-------w_1-> 14:36:05.523936; lasting 0:00:00.020386 seconds
# check point-------w_2-> 14:39:11.658827; lasting 0:03:06.134891 seconds
# check point-------w_3-> 14:39:11.664121; lasting 0:00:00.005294 seconds
# check point-------o_0-> 14:39:11.664166; lasting 0:00:00.000045 seconds
# Epoch: 6000
# Train loss: 0.0355
# dEI: 1.9683
# term1: 2.6454
# term2: 1.2911
# Test multistep loss: 0.2017
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 14:39:23.543842; lasting 0:00:11.879676 seconds
# check point-------o_0-> 14:42:48.742283; lasting 0:03:25.198441 seconds
# Epoch: 6500
# Train loss: 0.0261
# dEI: 1.9823
# term1: 2.6721
# term2: 1.2925
# Test multistep loss: 0.2026
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 14:43:01.072537; lasting 0:00:12.330254 seconds
# check point-------w_0-> 14:46:03.091273; lasting 0:03:02.018736 seconds
# check point-------w_1-> 14:46:03.126961; lasting 0:00:00.035688 seconds
# check point-------w_2-> 14:49:01.085318; lasting 0:02:57.958357 seconds
# check point-------w_3-> 14:49:01.088689; lasting 0:00:00.003371 seconds
# check point-------o_0-> 14:49:01.088732; lasting 0:00:00.000043 seconds
# Epoch: 7000
# Train loss: 0.0306
# dEI: 2.0142
# term1: 2.7358
# term2: 1.2925
# Test multistep loss: 0.2071
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 14:49:13.362927; lasting 0:00:12.274195 seconds
# check point-------o_0-> 14:52:36.853574; lasting 0:03:23.490647 seconds
# Epoch: 7500
# Train loss: 0.0268
# dEI: 2.0352
# term1: 2.7877
# term2: 1.2826
# Test multistep loss: 0.2040
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 14:52:48.719654; lasting 0:00:11.866080 seconds
# check point-------w_0-> 14:55:57.700597; lasting 0:03:08.980943 seconds
# check point-------w_1-> 14:55:57.718096; lasting 0:00:00.017499 seconds
# check point-------w_2-> 14:59:00.155448; lasting 0:03:02.437352 seconds
# check point-------w_3-> 14:59:00.159237; lasting 0:00:00.003789 seconds
# check point-------o_0-> 14:59:00.159274; lasting 0:00:00.000037 seconds
# Epoch: 8000
# Train loss: 0.0271
# dEI: 2.0272
# term1: 2.7788
# term2: 1.2756
# Test multistep loss: 0.2104
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 14:59:11.573629; lasting 0:00:11.414355 seconds
# check point-------o_0-> 15:02:22.435424; lasting 0:03:10.861795 seconds
# Epoch: 8500
# Train loss: 0.0269
# dEI: 2.0447
# term1: 2.8193
# term2: 1.2700
# Test multistep loss: 0.2047
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 15:02:36.106394; lasting 0:00:13.670970 seconds
# check point-------w_0-> 15:05:48.468213; lasting 0:03:12.361819 seconds
# check point-------w_1-> 15:05:48.485320; lasting 0:00:00.017107 seconds
# check point-------w_2-> 15:08:52.165471; lasting 0:03:03.680151 seconds
# check point-------w_3-> 15:08:52.169255; lasting 0:00:00.003784 seconds
# check point-------o_0-> 15:08:52.169298; lasting 0:00:00.000043 seconds
# Epoch: 9000
# Train loss: 0.0279
# dEI: 2.0700
# term1: 2.8719
# term2: 1.2681
# Test multistep loss: 0.2025
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 15:09:03.806797; lasting 0:00:11.637499 seconds
# check point-------o_0-> 15:12:11.783727; lasting 0:03:07.976930 seconds
# Epoch: 9500
# Train loss: 0.0316
# dEI: 2.0596
# term1: 2.8677
# term2: 1.2514
# Test multistep loss: 0.2124
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 15:12:22.764000; lasting 0:00:10.980273 seconds
# check point-------w_0-> 15:15:49.876797; lasting 0:03:27.112797 seconds
# check point-------w_1-> 15:15:49.888780; lasting 0:00:00.011983 seconds
# check point-------w_2-> 15:18:51.093079; lasting 0:03:01.204299 seconds
# check point-------w_3-> 15:18:51.100041; lasting 0:00:00.006962 seconds
# check point-------o_0-> 15:18:51.100136; lasting 0:00:00.000095 seconds
# Epoch: 10000
# Train loss: 0.0429
# dEI: 2.1022
# term1: 2.9645
# term2: 1.2399
# Test multistep loss: 0.1998
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 15:19:05.516392; lasting 0:00:14.416256 seconds
# check point-------o_0-> 15:22:36.286262; lasting 0:03:30.769870 seconds
# Epoch: 10500
# Train loss: 0.0293
# dEI: 2.1120
# term1: 2.9864
# term2: 1.2375
# Test multistep loss: 0.2065
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1->
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 16:41:24.869992; lasting 0:00:13.524004 seconds
# check point-------w_0-> 16:44:37.711274; lasting 0:03:12.841282 seconds
# check point-------w_1-> 16:44:37.728553; lasting 0:00:00.017279 seconds
# check point-------w_2-> 16:47:44.335065; lasting 0:03:06.606512 seconds
# check point-------w_3-> 16:47:44.338431; lasting 0:00:00.003366 seconds
# check point-------o_0-> 16:47:44.338476; lasting 0:00:00.000045 seconds
# Epoch: 19000
# Train loss: 0.0254
# dEI: 2.1402
# term1: 3.1852
# term2: 1.0953
# Test multistep loss: 0.1999
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 16:47:55.796203; lasting 0:00:11.457727 seconds
# check point-------o_0-> 16:50:54.874516; lasting 0:02:59.078313 seconds
# Epoch: 19500
# Train loss: 0.0425
# dEI: 2.1280
# term1: 3.1638
# term2: 1.0923
# Test multistep loss: 0.1985
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 16:51:10.340282; lasting 0:00:15.465766 seconds
# check point-------w_0-> 16:54:08.804118; lasting 0:02:58.463836 seconds
# check point-------w_1-> 16:54:08.818847; lasting 0:00:00.014729 seconds
# check point-------w_2-> 16:57:15.648290; lasting 0:03:06.829443 seconds
# check point-------w_3-> 16:57:15.660703; lasting 0:00:00.012413 seconds
# check point-------o_0-> 16:57:15.660775; lasting 0:00:00.000072 seconds
# Epoch: 20000
# Train loss: 0.0481
# dEI: 2.1392
# term1: 3.2030
# term2: 1.0754
# Test multistep loss: 0.2138
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 16:57:26.881336; lasting 0:00:11.220561 seconds
# check point-------o_0-> 17:00:38.795323; lasting 0:03:11.913987 seconds
# Epoch: 20500
# Train loss: 0.0259
# dEI: 2.1420
# term1: 3.2104
# term2: 1.0736
# Test multistep loss: 0.2036
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:00:50.893671; lasting 0:00:12.098348 seconds
# check point-------w_0-> 17:04:00.645661; lasting 0:03:09.751990 seconds
# check point-------w_1-> 17:04:00.673898; lasting 0:00:00.028237 seconds
# check point-------w_2-> 17:07:02.614623; lasting 0:03:01.940725 seconds
# check point-------w_3-> 17:07:02.618599; lasting 0:00:00.003976 seconds
# check point-------o_0-> 17:07:02.618645; lasting 0:00:00.000046 seconds
# Epoch: 21000
# Train loss: 0.0265
# dEI: 2.1326
# term1: 3.1875
# term2: 1.0776
# Test multistep loss: 0.1966
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:07:14.122800; lasting 0:00:11.504155 seconds
# check point-------o_0-> 17:10:27.176270; lasting 0:03:13.053470 seconds
# Epoch: 21500
# Train loss: 0.0272
# dEI: 2.1346
# term1: 3.2167
# term2: 1.0525
# Test multistep loss: 0.1993
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:10:38.428208; lasting 0:00:11.251938 seconds
# check point-------w_0-> 17:13:57.981023; lasting 0:03:19.552815 seconds
# check point-------w_1-> 17:13:58.002899; lasting 0:00:00.021876 seconds
# check point-------w_2-> 17:16:54.066380; lasting 0:02:56.063481 seconds
# check point-------w_3-> 17:16:54.082133; lasting 0:00:00.015753 seconds
# check point-------o_0-> 17:16:54.082179; lasting 0:00:00.000046 seconds
# Epoch: 22000
# Train loss: 0.0249
# dEI: 2.1558
# term1: 3.2518
# term2: 1.0598
# Test multistep loss: 0.1978
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:17:08.135631; lasting 0:00:14.053452 seconds
# check point-------o_0-> 17:20:26.468035; lasting 0:03:18.332404 seconds
# Epoch: 22500
# Train loss: 0.0290
# dEI: 2.1432
# term1: 3.2368
# term2: 1.0496
# Test multistep loss: 0.1919
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:20:37.742087; lasting 0:00:11.274052 seconds
# check point-------w_0-> 17:23:47.027130; lasting 0:03:09.285043 seconds
# check point-------w_1-> 17:23:47.038882; lasting 0:00:00.011752 seconds
# check point-------w_2-> 17:26:52.013621; lasting 0:03:04.974739 seconds
# check point-------w_3-> 17:26:52.016986; lasting 0:00:00.003365 seconds
# check point-------o_0-> 17:26:52.017023; lasting 0:00:00.000037 seconds
# Epoch: 23000
# Train loss: 0.0252
# dEI: 2.1453
# term1: 3.2488
# term2: 1.0417
# Test multistep loss: 0.1998
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:27:03.919121; lasting 0:00:11.902098 seconds
# check point-------o_0-> 17:30:13.912536; lasting 0:03:09.993415 seconds
# Epoch: 23500
# Train loss: 0.0256
# dEI: 2.1400
# term1: 3.2367
# term2: 1.0432
# Test multistep loss: 0.2021
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:30:27.597100; lasting 0:00:13.684564 seconds
# check point-------w_0-> 17:33:34.392160; lasting 0:03:06.795060 seconds
# check point-------w_1-> 17:33:34.402422; lasting 0:00:00.010262 seconds
# check point-------w_2-> 17:36:38.490097; lasting 0:03:04.087675 seconds
# check point-------w_3-> 17:36:38.493382; lasting 0:00:00.003285 seconds
# check point-------o_0-> 17:36:38.493422; lasting 0:00:00.000040 seconds
# Epoch: 24000
# Train loss: 0.0248
# dEI: 2.1521
# term1: 3.2835
# term2: 1.0207
# Test multistep loss: 0.2031
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:36:50.747475; lasting 0:00:12.254053 seconds
# check point-------o_0-> 17:39:56.884583; lasting 0:03:06.137108 seconds
# Epoch: 24500
# Train loss: 0.0300
# dEI: 2.1249
# term1: 3.2306
# term2: 1.0192
# Test multistep loss: 0.1909
# ------------------------------------------------------------------------------------------------------------------------
# check point-------o_1-> 17:40:08.666350; lasting 0:00:11.781767 seconds

# %% [markdown]
# # Plot

# %%
from vector_field import vector_func
sz = 4
scale = 2
L = 1
sigma = 0.03
rou = -0.5
hidden_units = 64
nis = Renorm_Dynamic(sym_size = sz, latent_size = scale, effect_size = sz, 
                         hidden_units = hidden_units, normalized_state=True, device = device)
nisp = Renorm_Dynamic(sym_size = sz, latent_size = scale, effect_size = sz, 
                         hidden_units = hidden_units, normalized_state=True, device = device)
nis.to(device=device)
nisp.to(device=device)
nis.load_state_dict(torch.load(f'mdl_data/nis steps10 exp-0.2t interval100 seed={seed}.mdl'))
nisp.load_state_dict(torch.load(f'mdl_data/nisp steps10 exp-0.2t interval100 seed={seed}.mdl'))



dd1_nis,dd2_nis=vector_func(nis,sigma=sigma,rou=rou, jac_bool=False, density=0.007,density2=0.015,density3=0.07)
dd1_nis_jac,dd2_nis_jac=vector_func(nis,sigma=sigma,rou=rou, jac_bool=True,density=0.007,density2=0.015,density3=0.07)
dd1_nisp,dd2_nisp=vector_func(nisp,sigma=sigma,rou=rou, jac_bool=False,density=0.007,density2=0.015,density3=0.07)
dd1_nisp_jac,dd2_nisp_jac=vector_func(nisp,sigma=sigma,rou=rou, jac_bool=True,density=0.007,density2=0.015,density3=0.07)
# Out:
# /home/yuanbing/data/test/ymz_nis/Code-for-Finding-emergence-in-data-/exp/sir/vector_field.py:94: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1708025831440/work/torch/csrc/utils/tensor_new.cpp:275.)
#   dSdt=torch.tensor([dSdt],device=device,dtype=torch.float).t()
# /home/yuanbing/data/test/ymz_nis/Code-for-Finding-emergence-in-data-/exp/sir/vector_field.py:76: RuntimeWarning: invalid value encountered in scalar divide
#   count_mean[i,j,0]=np.sum(x_m)/np.sum(count[i,j,:,:].cpu().detach().numpy())
# /home/yuanbing/data/test/ymz_nis/Code-for-Finding-emergence-in-data-/exp/sir/vector_field.py:77: RuntimeWarning: invalid value encountered in scalar divide
#   count_mean[i,j,1]=np.sum(y_m)/np.sum(count[i,j,:,:].cpu().detach().numpy())

# %%
import matplotlib
def SIR(s,i,lam=1,miu=0.5):
    ds=-lam * s * i
    di=lam * s * i - miu * i
    return ds, di
S, I = mesh(0.07)
dSdt,dIdt = SIR(S,I)
m=0.1
dSdt,dIdt=m*dSdt,m*dIdt
fig,ax = plt.subplots(figsize=(5,4),dpi=150)
colorlabel = ['#F4F1DE','#DF7A5E','#3C405B','#82B29A','#F2CC8E']
colors=[colorlabel[2]]*len(S)+[colorlabel[3]]*len(S)+[colorlabel[1]]*len(S)
S=list(S)+list(S)+list(S)
I=list(I)+list(I)+list(I)
dd1_final=list(dd1_nis)+list(dd1_nis_jac)+list(dSdt)
dd2_final=list(dd2_nis)+list(dd2_nis_jac)+list(dIdt)

quiver = ax.quiver(S, I, dd1_final, dd2_final, width=0.005,color=colors)
red_patch = matplotlib.patches.Patch(color=colorlabel[1], label='real')
green_patch = matplotlib.patches.Patch(color=colorlabel[2], label='NIS')
ran_patch = matplotlib.patches.Patch(color=colorlabel[3], label='theoretic')
plt.legend(handles=[red_patch, green_patch,ran_patch],loc='best', fontsize=12)

# Set graphic title and axis labels.
plt.xlabel('$S(h_1)$',fontsize=15)
plt.ylabel('$I(h_2)$',fontsize=15)

ax.tick_params(labelsize=15)
plt.show()

# %%
def SIR(s,i,lam=1,miu=0.5):
    ds=-lam * s * i
    di=lam * s * i - miu * i
    return ds, di
S, I = mesh(0.07)
dSdt,dIdt = SIR(S,I)
m=0.1
dSdt,dIdt=m*dSdt,m*dIdt
fig,ax = plt.subplots(figsize=(5,4),dpi=150)
colorlabel = ['#F4F1DE','#DF7A5E','#3C405B','#82B29A','#F2CC8E']
colors=[colorlabel[2]]*len(S)+[colorlabel[3]]*len(S)+[colorlabel[1]]*len(S)
S=list(S)+list(S)+list(S)
I=list(I)+list(I)+list(I)
dd1_final=list(dd1_nisp)+list(dd1_nisp_jac)+list(dSdt)
dd2_final=list(dd2_nisp)+list(dd2_nisp_jac)+list(dIdt)

quiver = ax.quiver(S, I, dd1_final, dd2_final, width=0.005,color=colors)
red_patch = matplotlib.patches.Patch(color=colorlabel[1], label='real')
green_patch = matplotlib.patches.Patch(color=colorlabel[2], label='NIS+')
ran_patch = matplotlib.patches.Patch(color=colorlabel[3], label='theoretic')
plt.legend(handles=[red_patch, green_patch,ran_patch],loc='best', fontsize=12)

# Set graphic title and axis labels.
plt.xlabel('$S(h_1)$',fontsize=15)
plt.ylabel('$I(h_2)$',fontsize=15)

ax.tick_params(labelsize=15)
plt.show()
